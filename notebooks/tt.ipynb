# %%
from smart_predict.modules.base.custom import CustomModule
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-daadc319a324> in <module>
# ----> 1 from smart_predict.modules.base.custom import CustomModule
#
# ModuleNotFoundError: No module named 'smart_predict'

# %%
from smartpredict.modules.base.custom import CustomModule
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-cd04b707da99> in <module>
# ----> 1 from smartpredict.modules.base.custom import CustomModule
#
# ModuleNotFoundError: No module named 'smartpredict.modules'
